# %%
import pandas as pd
import numpy as np 
import torch 
import os, random

# %%
import pandas as pd # Import the library, usually aliased as 'pd'

# The correct way:
dataset = pd.read_csv("submission.csv")

# %%
# !pip install torch
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1385879126.py in <cell line: 0>()
# ----> 1 dataset = csv_read("submission.csv")
#
# NameError: name 'csv_read' is not defined
